# %% [markdown]
# <a href="https://colab.research.google.com/github/TRACE-Structures/bimquake/blob/main/demo/notebooks/bimquake_pilot_Palazzo_Poniatowski_Guadagni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Earthquake Resilience with pilot building**

# %% [markdown]
# This Jupyter Notebook demonstrates the functions of the **Assessment of Earthquake Resilience** module with the example of the two-storey Palazzo Poniatowski Guadagni building.
#
# The module implements linear and non-linear computations and visualizations for analyzing the earthquake resilience of a given building.

# %% [markdown]
# ### Imports

# %%
! pip install bimquake

# %%
import bimquake
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data inputs

# %% [markdown]
# The following user inputs are needed for the calculations:
# - latitude and longitude of the building (in decimal degrees)
# - soil category - ranges from hard rock (`A`) to very soft or problematic soils (`E`)
# - nominal life - the intended design service life of the structure (in years)
# - topographic category - the influence of terrain features (such as hills and ridges) on wind or seismic effects. Ranges from `T1` (no inpact, flat terrain) to `T4` (upper half of a ridge, maximum amplification)
# - importance class - the criticality of a structure, influences the level of seismic safety required
#     - Class `I`: Low importance (e. g., agricultural or temporary building)
#     - Class `II`: Ordinary structure (standard residential, commercial or office building)
#     - Class `III`: Building with high occupancy or social importance (e.g., school, assembly hall)
#     - Class `IV`: Essential facility and structure of vital importance for civil protection, which must remain operational after an earthquake (e.g., hospital, emergency center)
# - `.xls` or `.xlsx` file with wall properties of the building in a predefined [format](https://buildchain.ilab.sztaki.hu/templates)

# %%
data_path = 'https://raw.githubusercontent.com/TRACE-Structures/bimquake/main/demo/data/PalazzoPoniatowski_pilot.xlsx'
excel_file = pd.ExcelFile(data_path)
S = bimquake.create_equivalent_frame_model_from_excel(excel_file)

# %% [markdown]
# ### Coordinate check

# %%
latitude = 43.7874
longitude = 11.2499

# %%
ParaTR, city, country = bimquake.get_Parameters(latitude, longitude)
print("{}, {}".format(city, country))
# Out:
# Loading formatted geocoded file...
# Florence, IT

# %%
f = bimquake.get_map(latitude, longitude, city, country)
f
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a29f4a64bed825650f35bdab86e9f8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a29f4a64bed825650f35bdab86e9f8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a29f4a64bed825650f35bdab86e9f8f = L.map(
#                 &quot;map_9a29f4a64bed825650f35bdab86e9f8f&quot;,
#                 {
#                     center: [43.7874, 11.2499],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a67861f2b0a8d96f3f8dfc71b57eccde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a67861f2b0a8d96f3f8dfc71b57eccde.addTo(map_9a29f4a64bed825650f35bdab86e9f8f);
#
#
#             var marker_e724db812a420f689954acfab10251b6 = L.marker(
#                 [43.7874, 11.2499],
#                 {
# }
#             ).addTo(map_9a29f4a64bed825650f35bdab86e9f8f);
#
#
#             var icon_a40e1a19405be0f98bc64180430f248f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f4e30e3f200d586f3e117612952db9dc = L.popup({
#   &quot;maxWidth&quot;: 400,
#   &quot;minWidth&quot;: 80,
# });
#
#
#
#                 var html_d49eb2338a3be3a5dab964eafbf4e3f3 = $(`&lt;div id=&quot;html_d49eb2338a3be3a5dab964eafbf4e3f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Florence, IT&lt;/b&gt;&lt;br&gt;(43° 47&#x27; 15&quot; N 11° 14&#x27; 60&quot; E)&lt;/div&gt;`)[0];
#                 popup_f4e30e3f200d586f3e117612952db9dc.setContent(html_d49eb2338a3be3a5dab964eafbf4e3f3);
#
#
#
#         marker_e724db812a420f689954acfab10251b6.bindPopup(popup_f4e30e3f200d586f3e117612952db9dc)
#         ;
#
#
#
#
#                 marker_e724db812a420f689954acfab10251b6.setIcon(icon_a40e1a19405be0f98bc64180430f248f);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="500" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
ParaTR
# Out:
#    Return Period        ag        Fo       Tc*
# 0           30.0  0.047018  2.551014  0.252808
# 1           50.0  0.056464  2.586081  0.267521
# 2           72.0  0.064100  2.593636  0.276378
# 3          101.0  0.072345  2.590411  0.281871
# 4          140.0  0.080685  2.597692  0.287275
# 5          201.0  0.093504  2.531818  0.293817
# 6          475.0  0.131090  2.420610  0.301819
# 7          975.0  0.167652  2.390029  0.310319
# 8         2475.0  0.221719  2.411010  0.318801

# %% [markdown]
# ### Settings

# %%
soil_category = 'A'
nominal_life = 50
topographic_category = 'T1'
importance_class = 'I'

# %%
S.set_location(latitude, longitude)
S.set_seismic_loading(ParaTR)
S.set_seismic_design_parameters(soil_category, nominal_life, topographic_category, importance_class)
# Out:
# servicee life: 50
# importance class: I
# class: I

# %% [markdown]
# ### 2D layout

# %%
floor_id = 0
S.plot_floor_layout(floor_id)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32df21d8-7ca7-49af-a689-492bb4b53dcb" class="plotly-graph-div" style="height:800px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32df21d8-7ca7-49af-a689-492bb4b53dcb")) {                    Plotly.newPlot(                        "32df21d8-7ca7-49af-a689-492bb4b53dcb",                        [{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W1","showlegend":false,"text":"\u003cb\u003eWall F0_W1\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[4.126259225655642,3.4038928914885993,3.753740774344358,4.476107108511401,4.126259225655642],"y":[9.448553605868117,8.145370242230417,7.951446394131882,9.254629757769582,9.448553605868117],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W2","showlegend":false,"text":"\u003cb\u003eWall F0_W2\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[6.770745800328842,4.5794063168153984,4.929254199671157,7.120593683184601,6.770745800328842],"y":[14.273602462184302,10.320321385914232,10.126397537815697,14.079678614085767,14.273602462184302],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W3","showlegend":false,"text":"\u003cb\u003eWall F0_W3\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[9.17560030919066,7.1345518079535815,7.48439969080934,9.525448192046419,9.17560030919066],"y":[18.698036407577696,15.01588744052084,14.821963592422305,18.50411255947916,18.698036407577696],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W4","showlegend":false,"text":"\u003cb\u003eWall F0_W4\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[10.744151810468193,10.36600030667605,10.715848189531808,11.093999693323951,10.744151810468193],"y":[20.96806360983363,20.285860238264906,20.09193639016637,20.774139761735096,20.96806360983363],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W5","showlegend":false,"text":"\u003cb\u003eWall F0_W5\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[7.629926240350543,7.082091369472182,7.410073759649456,7.957908630527817,7.629926240350543],"y":[6.775061938329947,5.7867416692624305,5.604938061670054,6.59325833073757,6.775061938329947],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W6","showlegend":false,"text":"\u003cb\u003eWall F0_W6\u003c\u002fb\u003e\u003cbr\u003eshear wall in dir Y","x":[8.438400789715823,7.633616820106902,7.961599210284176,8.766383179893095,8.438400789715823],"y":[8.236836160721886,6.78496744687049,6.603163839278113,8.05503255312951,8.236836160721886],"type":"scatter"},{"fill":"toself","fillcolor":"#ff6600","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"line ...

# %% [markdown]
# ### Linear analysis calculation

# %%
q = 1.5
q_ort = 3

Sfs = S.run_linear_static_analysis(q, q_ort)

# %%
chosen_floor = 0
Sfs[chosen_floor]
# Out:
#      Wall_ID     SF_VY     SF_MY    SF_MOY     SF_VX     SF_MX    SF_MOX
# 0          1  1.819418  1.403859  1.009444       NaN       NaN       NaN
# 1          2  1.546189  3.466228  0.821606       NaN       NaN       NaN
# 2          3  1.887866  4.118141  1.048007       NaN       NaN       NaN
# 3          4  1.046164  0.100468  0.138000       NaN       NaN       NaN
# 4          5  1.868187  1.093924  0.972355       NaN       NaN       NaN
# ..       ...       ...       ...       ...       ...       ...       ...
# 118      119  2.863381  0.860940  1.738646       NaN       NaN       NaN
# 119      120  3.053267  1.866242  1.826431       NaN       NaN       NaN
# 120      121  3.251782  3.291448  1.920920       NaN       NaN       NaN
# 121      122       NaN       NaN       NaN  3.064865  2.260544  1.369074
# 122      123  1.741243  0.897853  0.853726       NaN       NaN       NaN
#
# [123 rows x 7 columns]

# %%
direction = 'Y' # or 'X'
floor_id = 0
safety_factor_type = 'Shear' # or 'Bending in plane' or 'Bending out of plane'

S.plot_wall_safety_factors(Sfs, direction, floor_id, safety_factor_type)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f777030-d063-422f-a2aa-ff8b845530ca" class="plotly-graph-div" style="height:800px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f777030-d063-422f-a2aa-ff8b845530ca")) {                    Plotly.newPlot(                        "2f777030-d063-422f-a2aa-ff8b845530ca",                        [{"fill":"toself","fillcolor":"rgb(0, 156, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W1","showlegend":false,"text":"\u003cb\u003eWall F0_W1\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.82","x":[4.126259225655642,3.4038928914885993,3.753740774344358,4.476107108511401,4.126259225655642],"y":[9.448553605868117,8.145370242230417,7.951446394131882,9.254629757769582,9.448553605868117],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(0, 241, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W2","showlegend":false,"text":"\u003cb\u003eWall F0_W2\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.55","x":[6.770745800328842,4.5794063168153984,4.929254199671157,7.120593683184601,6.770745800328842],"y":[14.273602462184302,10.320321385914232,10.126397537815697,14.079678614085767,14.273602462184302],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(0, 135, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W3","showlegend":false,"text":"\u003cb\u003eWall F0_W3\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.89","x":[9.17560030919066,7.1345518079535815,7.48439969080934,9.525448192046419,9.17560030919066],"y":[18.698036407577696,15.01588744052084,14.821963592422305,18.50411255947916,18.698036407577696],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(250, 151, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W4","showlegend":false,"text":"\u003cb\u003eWall F0_W4\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.05","x":[10.744151810468193,10.36600030667605,10.715848189531808,11.093999693323951,10.744151810468193],"y":[20.96806360983363,20.285860238264906,20.09193639016637,20.774139761735096,20.96806360983363],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(0, 141, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W5","showlegend":false,"text":"\u003cb\u003eWall F0_W5\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.87","x":[7.629926240350543,7.082091369472182,7.410073759649456,7.957908630527817,7.629926240350543],"y":[6.775061938329947,5.7867416692624305,5.604938061670054,6.59325833073757,6.775061938329947],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(0, 133, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W6","showlegend":false,"text":"\u003cb\u003eWall F0_W6\u003c\u002fb\u003e\u003cbr\u003eSafety factor: 1.89","x":[8.438400789715823,7.633616820106902,7.961599210284176,8.766383179893095,8.438400789715823],"y":[8.236836160721886,6.78496744687049,6.603163839278113,8.05503255312951,8.236836160721886],"type":"scatter"},{"fill":"toself","fillcolor":"rgb(0, 225, 0)","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u00 ...

# %% [markdown]
# ### Pushover analysis calculation

# %%
method = 'Ductility' # or 'Drift'
algorithm = 'incr' # or 'add' (Incremental or Additive)
mu = 1.5

# %%
k_ult_TOT, Hult_TOT, vr_ult_TOT, L_organized = S.get_force_displacement_capacity_curve(method, algorithm, mu)
v_bl, H_bl = S.get_bilinear_capacity_curve_coords(vr_ult_TOT, Hult_TOT)
pushover_results = S.assess_seismic_performance_get_ADRS_params(k_ult_TOT, Hult_TOT, vr_ult_TOT, H_bl, v_bl)

# %% [markdown]
# ### Outputs

# %%
df2 = S.get_global_vulnerability_metrics(v_bl, pushover_results)
df2
# Out:
#   Direction Safety Index PGA_C      TR      δ d* (t)
# 0         X          1.7   0.2  1590.0   20.0  20.85
# 1         Y         1.02  0.12   350.0  12.27  22.15

# %%
fig1 = S.plot_capacity_curve(vr_ult_TOT, Hult_TOT, v_bl, H_bl)

# %%
fig2 = S.plot_ADRS_demand_and_capacity(v_bl, pushover_results)

# %%
direction = 'X' # or 'Y'
floor_id = 0

S.plot_failing_walls(L_organized, 'X', floor_id)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12f44855-b3a1-433a-a090-ae54a279aad6" class="plotly-graph-div" style="height:800px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12f44855-b3a1-433a-a090-ae54a279aad6")) {                    Plotly.newPlot(                        "12f44855-b3a1-433a-a090-ae54a279aad6",                        [{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W1","showlegend":false,"text":"\u003cb\u003eWall F0_W1\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[4.126259225655642,3.4038928914885993,3.753740774344358,4.476107108511401,4.126259225655642],"y":[9.448553605868117,8.145370242230417,7.951446394131882,9.254629757769582,9.448553605868117],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W2","showlegend":false,"text":"\u003cb\u003eWall F0_W2\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[6.770745800328842,4.5794063168153984,4.929254199671157,7.120593683184601,6.770745800328842],"y":[14.273602462184302,10.320321385914232,10.126397537815697,14.079678614085767,14.273602462184302],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W3","showlegend":false,"text":"\u003cb\u003eWall F0_W3\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[9.17560030919066,7.1345518079535815,7.48439969080934,9.525448192046419,9.17560030919066],"y":[18.698036407577696,15.01588744052084,14.821963592422305,18.50411255947916,18.698036407577696],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W4","showlegend":false,"text":"\u003cb\u003eWall F0_W4\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[10.744151810468193,10.36600030667605,10.715848189531808,11.093999693323951,10.744151810468193],"y":[20.96806360983363,20.285860238264906,20.09193639016637,20.774139761735096,20.96806360983363],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W5","showlegend":false,"text":"\u003cb\u003eWall F0_W5\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[7.629926240350543,7.082091369472182,7.410073759649456,7.957908630527817,7.629926240350543],"y":[6.775061938329947,5.7867416692624305,5.604938061670054,6.59325833073757,6.775061938329947],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W6","showlegend":false,"text":"\u003cb\u003eWall F0_W6\u003c\u002fb\u003e\u003cbr\u003eNot failing","x":[8.438400789715823,7.633616820106902,7.961599210284176,8.766383179893095,8.438400789715823],"y":[8.236836160721886,6.78496744687049,6.603163839278113,8.05503255312951,8.236836160721886],"type":"scatter"},{"fill":"toself","fillcolor":"#E5E4E2","hoverlabel":{"namelength":0},"hoveron":"fills","hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"black","width":1},"mode":"lines","name":"Wall F0_W7","showlegend":false,"text" ...
